# %%
print('Olá Mundo ', 'Esse é meu', 'primeiro programa')
# Out:
# Olá Mundo  Esse é meu primeiro programa

# %%
print('Olá meu nome é {} e tenho {} anos'.format('Paulo', '20'))
# Out:
# Olá meu nome é Paulo e tenho 20 anos

# %%
input('Quantos anos você tem? ')
# Out:
# Quantos anos você tem? 20
# '20'

# %%
print('Eu estudo no {}'.format(input('Onde você estuda? ')))
# Out:
# Onde você estuda? Senac
# Eu estudo no Senac

# %%
#Qual seu endereço...
print('Meu endereço é Rua {}, {}, {}, {}/SP'.
      format(input('Qual sua Rua: '), input('Qual o Nº: '),
             input('Qual o Bairro: '), input('Qual a Cidade: ')))
# Out:
# Qual sua Rua: Angelo Ortolan
# Qual o Nº: 150
# Qual o Bairro: Lot. Ind. Machadinho
# Meu endereço é Rua Angelo Ortolan, 150, Lot. Ind. Machadinho, Americana/SP

# %%
'''
salaOndeVaiTerCursoPython = camelCase
sala_onde_vai_ter_curso_python = snake_case
sala-onde-vai-ter-curso-python = kebab-case
'''

nome = input('Qual o seu nome? ')
sobrenome = input('Qual seu sobrenome')
idade = input('Qual a sua idade? ')

print('Olá me chamo {} {} e tenho {} anos  ' .format(nome, sobrenome, idade))
# Out:
# Qual o seu nome? paulo
# Qual seu sobrenomesantos
# Qual a sua idade? 20
# Olá me chamo paulo santos e tenho 20 anos
